# %% [markdown]
# # Notebook for them to visualize the mass halo function

# %%
# imports
import numpy as np
import matplotlib.pyplot as plt

# %%
# create some mock data to see how plotting histograms work
data = np.random.normal(0, 1, 100)
#plot the histogram
plt.hist(data, bins=3, alpha=0.5, color='b')
plt.show()

# %%
# create your own lists of data using your box of rocks
small = []
medium = []
large = []

# plot the histogram with your own data of box of rocks

# %%
import numpy as np
import matplotlib.pyplot as plt

# masses = []  # Replace with actual mass values
# bin_edges = [34, 38]

small_bin_edge = 30
light_bin_edge = 40
medium_bin_edge = 50
heavy_bin_edge = 60
masses = [34, 36, 35, 38, 40, 42, 44, 46, 48, 50, 52, 54, 56, 58, 60]  # Replace with actual mass values
bin_edges = [small_bin_edge, light_bin_edge, medium_bin_edge, heavy_bin_edge]

plt.hist(masses, bins=bin_edges, edgecolor='black')
plt.xlabel('Mass (g)')
plt.ylabel('Number of Rocks')
plt.title('Distribution of Rock Masses')
plt.show()
